# %%
# %ls
# Out:
# adult.csv                  coches.csv            pokemon.csv
# airline_data.csv           cwurData.csv          README.md
# antropometria00.csv        data.csv              reg_data.csv
# antropometria-dataset.csv  datasets/             requirements.txt
# Book3.csv                  headbrain.csv         sample_pivot.csv
# Canada.xlsx                mic2.xlsx             tips.csv
# Cartwheeldata.csv          mic.xlsx              Untitled1.ipynb
# census.csv                 movies.csv            Untitled.ipynb
# Class1                     nhanes_2015_2016.csv  weight-height.csv

# %%
# %ls datasets\
# Out:
# ls: cannot access 'datasets\': No such file or directory

# %%
# %ls datasets/
# Out:
# adult.csv                  census.csv     movies.csv
# airline_data.csv           coches.csv     nhanes_2015_2016.csv
# antropometria00.csv        cwurData.csv   pokemon.csv
# antropometria-dataset.csv  data.csv       reg_data.csv
# Book3.csv                  headbrain.csv  sample_pivot.csv
# Canada.xlsx                mic2.xlsx      tips.csv
# Cartwheeldata.csv          mic.xlsx       weight-height.csv

# %%
import pandas as pd

# %%
pip install xlrd
# Out:
# ...
#      |████████████████████████████████| 96 kB 5.7 MB/s
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
path ='datasets/Canada.xlsx'

# %%
pip install openpyxl
# Out:
# ...
#      |████████████████████████████████| 242 kB 2.3 MB/s
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_excel(path,
                   engine = 'openpyxl',
                   sheet_name = 'Canada by Citizenship',
                   skiprows = range(20),
                   skipfooter = 2
                  )
df.head(2)
# Out:
#          Type    Coverage       OdName   AREA AreaName     REG  \
# 0  Immigrants  Foreigners  Afghanistan  935.0     Asia  5501.0
# 1  Immigrants  Foreigners      Albania  908.0   Europe   925.0
#
#            RegName    DEV             DevName  1980  ...    2012    2013  \
# 0    Southern Asia  902.0  Developing regions  16.0  ...  2635.0  2004.0
# 1  Southern Europe  901.0   Developed regions   1.0  ...   620.0   603.0
#
#    Unnamed: 43  Unnamed: 44  Unnamed: 45  Unnamed: 46  Unnamed: 47  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 48  Unnamed: 49  Unnamed: 50
# 0          NaN          NaN          NaN
# 1          NaN          NaN          NaN
#
# [2 rows x 51 columns]
