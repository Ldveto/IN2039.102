# %%
import pandas as pd
import numpy as np

# %%
# %ls datasets/
# Out:
# adult.csv                  census.csv     movies.csv
# airline_data.csv           coches.csv     nhanes_2015_2016.csv
# antropometria00.csv        cwurData.csv   pokemon.csv
# antropometria-dataset.csv  data.csv       reg_data.csv
# Book3.csv                  headbrain.csv  sample_pivot.csv
# Canada.xlsx                mic2.xlsx      tips.csv
# Cartwheeldata.csv          mic.xlsx       weight-height.csv

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
path = 'antropometria-dataset.csv'
df = pd.read_csv(path)
df.head(2)
# Out:
#     folio  intp  entidad desc_ent  sexo  edad  meses   peso  ropa  talla  ...  \
# 0  210295     2       21   PUEBLA     2    38      8  73.70     2  146.4  ...
# 1  101655     3       10  DURANGO     2    11     11  35.65     2  145.1  ...
#
#   hpresion tbrazo  htension  PrimaryLast  code_upm  est_dis est_urb est_marg  \
# 0    16:30      2     16:35            1     R2101        5       3        1
# 1    15:25      3     15:25            1     M1041        1       1        1
#
#         pondef  est_var
# 0  3470.002176      215
# 1   417.946672      101
#
# [2 rows x 26 columns]

# %%
x = df.columns.tolist()
x.sort()
x
# Out:
# ['PrimaryLast',
#  'cadera',
#  'cintura',
#  'code_upm',
#  'desc_ent',
#  'diastol',
#  'edad',
#  'emb',
#  'entidad',
#  'est_dis',
#  'est_marg',
#  'est_urb',
#  'est_var',
#  'folio',
#  'hpresion',
#  'htension',
#  'intp',
#  'meses',
#  'peso',
#  'pondef',
#  'ropa',
#  'sexo',
#  'sistol',
#  'talla',
#  'tbrazo',
#  'temb']

# %%
myPivot = pd.pivot_table(df,
                         index = ['desc_ent'],
                         values = ['peso'],
                         aggfunc = ['mean'],
                         #aggfunc en python average es el default en pivot table y en excel es la suma
                        
                        )
myPivot
# Out:
#                                       mean
#                                       peso
# desc_ent
# AGUASCALIENTES                   66.357786
# BAJA CALIFORNIA                  68.467270
# BAJA CALIFORNIA SUR              71.809198
# CAMPECHE                         65.418475
# CHIAPAS                          57.613775
# CHIHUAHUA                        66.656005
# COAHUILA DE ZARAGOZA             68.154142
# COLIMA                           68.743648
# DISTRITO FEDERAL                 65.119273
# DURANGO                          66.354922
# GUANAJUATO                       63.936390
# GUERRERO                         60.466315
# HIDALGO                          59.995917
# JALISCO                          66.697270
# MEXICO                           60.680850
# MICHOACAN DE OCAMPO              64.900000
# MORELOS                          63.541295
# NAYARIT                          66.541827
# NUEVO LEON                       67.239853
# ...

# %%
myPivot = pd.pivot_table(df,
                         index = ['desc_ent','sexo'],
                         values = ['peso'],
                         aggfunc = ['mean'],
                         #aggfunc en python average es el default en pivot table y en excel es la suma
                        
                        )

pd.set_option('display.max_rows',5000)


myPivot
# Out:
#                                            mean
#                                            peso
# desc_ent                        sexo
# AGUASCALIENTES                  1     69.985381
#                                 2     63.254292
# BAJA CALIFORNIA                 1     71.391818
#                                 2     65.893667
# BAJA CALIFORNIA SUR             1     75.561015
#                                 2     68.168959
# CAMPECHE                        1     68.622637
#                                 2     62.920493
# CHIAPAS                         1     58.365222
#                                 2     57.096111
# CHIHUAHUA                       1     68.892642
#                                 2     64.815295
# COAHUILA DE ZARAGOZA            1     68.873094
#                                 2     67.467348
# COLIMA                          1     70.998878
#                                 2     66.978393
# DISTRITO FEDERAL                1     69.460661
# ...

# %% [markdown]
# ### Explanation of Results

# %% [markdown]
# First, I opened the csv file with pandas in order to view the data in Python. Then, once I had access to the data, I proceeded to display the names of the columns so that I could identify the variables of interest for the activity, which in this case were weight ('peso'), state ('desc_ent'), and gender ('sexo'). After I identified them, I proceeded to create a Pivot Table that showed the average weight according to state and then, according to sex, so that the table is displayed in a more concise and legible way.
